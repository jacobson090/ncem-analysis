# %% [markdown]
# # Node-centric expression models (NCEM)
#
# ### Preprint: [Learning cell communication from spatial graphs of cells](https://www.biorxiv.org/content/10.1101/2021.07.11.451750v1) (Fischer, Schaar, Theis, 2021)
#
# ![title](https://raw.githubusercontent.com/theislab/ncem/main/docs/_static/img/concept.png)
#
# #### Spatial graphs of single cells
#
# * Typically derived from segmentation on spatial omics assays with sub cellular resolution (IMC, MERFISH, seqFISH, CODEX, …)
#
# * Describe “niches”: spatial arrangements of sets of cells that are often characteristic of tissues.
#     * Niches approximate emergent phenomena in tissues that are not clear from dissociated cells. [Schürch, C. M. et al., Cell 183, 838 (2020).]
#
# &nbsp;
#
#
# #### Node-centric expression models (NCEM)
#
# * relate niche composition on the level of cell type to the cell-wise gene expression states.
#     * This explains within-cell type gene expression variation.
#
# * Type-type dependencies can be encoded in parameters.
#
# ##### $\Rightarrow$ NCEM are graph neural networks
#
# &nbsp;
#
# #### Cell–cell dependencies may be caused by:
#
# * ligand-receptor-based communication between cells
# * physical interactions
# * membrane junctions
# * metabolite exchange
#
# Therefore, we consider the effects of niche composition on all genes, rather than on receptor signaling genes only.

# %% [markdown]
# ## Import packages

# %%
# %load_ext autoreload
# %autoreload 2

import ncem
import matplotlib.pyplot as plt
import pandas as pd
import scanpy as sc
sc.settings.set_figure_params(dpi=80)

import warnings
warnings.filterwarnings("ignore")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # 0. Loading the data with the predefined data loader

# %%
# data path
path = '/home/abdul-muqeeth/Desktop/ncem/ncem_tutorials/tutorials'

# %%
interpreter = ncem.interpretation.interpreter.InterpreterInteraction()
interpreter.get_data(
    data_origin='hartmann',
    data_path=path + '/data/hartmann/',
    radius=35,
    node_label_space_id='type',
    node_feature_space_id='standard',
)
print('\n Celldata metadata:', interpreter.data.celldata.uns['metadata'])
# Out:
# Loading data from raw files
# registering celldata
# collecting image-wise celldata
# adding graph-level covariates
# 100%|█████████████████████████████████████████████████████████| 58/58 [00:03<00:00, 18.23it/s]
# Loaded 58 images with complete data from 4 patients over 63747 cells with 36 cell features and 8 distinct celltypes.
# Mean of mean node degree per images across images: 4.416036
#
#  Celldata metadata: {'lateral_resolution': 0.390625, 'fn': ['scMEP_MIBI_singlecell/scMEP_MIBI_singlecell.csv', 'scMEP_sample_description.xlsx'], 'image_col': 'point', 'pos_cols': ['center_colcoord', 'center_rowcoord'], 'cluster_col': 'Cluster', 'cluster_col_preprocessed': 'Cluster_preprocessed', 'patient_col': 'donor'}

# %%
# node degrees for different radii
interpreter.data.plot_degree_vs_dist(
    max_distances=[0, 10, 50, 200, 1000],
    lateral_resolution=400/1024,
)
# Out:
# 0.0
# 1.000547499859607
# 10.193272571484671
# 128.1181909355233
# 1071.8057746883462

# %% [markdown]
# # 1. Grid searches over neighbourhood sizes

# %%
gs = ncem.train.GridSearchContainer(
    path + '/grid_searches_gen/', 
    gs_ids=[
        "210419_INTERACTIONS_BASELINE_NONE_NODES_IMAGE_1_HARTMANN",
        "210419_INTERACTIONS_MAX_NODES_IMAGE_1_HARTMANN",
    ],
    lateral_resolution = 400/1024
)
gs.load_gs()

gs.plot_best_model_by_hyperparam(
    graph_model_class='interactions',
    baseline_model_class='interactions_baseline',
    rename_levels = [
        ("model", {
            "INTERACTIONS_BASELINE_NONE_NODES_IMAGE_1": "baseline",
            "INTERACTIONS_MAX_NODES_IMAGE_1": "NCEM",
        })
    ],
    xticks=[0, 10, 50, 200, 1000],
)
# Out:
#   0%|                                                                   | 0/2 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 9
#       1 gs = ncem.train.GridSearchContainer(
#       2     path + '/grid_searches_gen/',
#       3     gs_ids=[
#    (...)
#       7     lateral_resolution = 400/1024
#       8 )
# ----> 9 gs.load_gs()
#      11 gs.plot_best_model_by_hyperparam(
#      12     graph_model_class='interactions',
#      13     baseline_model_class='interactions_baseline',
#    (...)
#      20     xticks=[0, 10, 50, 200, 1000],
#      21 )
#
# File ~/miniconda3/envs/ncem_38/lib/python3.8/site-packages/ncem/train/summaries.py:114, in GridSearchContainer.load_gs(self, expected_pickle, add_posterior_sampling_model, report_unsuccessful_runs)
#     106 indir = self.source_path + gs_id + "/results/"
#     107 # runs_ids are the unique hyper-parameter settings, which are again subsetted by cross-validation.
#     108 # These ids are present in all files names but are only collected from the *model.tf file names here.
#     110 run_ids = np.sort(
#     111     np.unique(
#     112         [
#     113             "_".join(".".join(x.split(".")[:-1]).split("_")[:-1])
# --> 114             for x in os.listdir(indir)
#     115             if x.split("_")[-1].split(".")[0] == "time"
#     116         ]
#     117     )
#     118 )
#     119 cv_ids = np.sort(
#     120     np.unique([x.split("_")[-1] for x in run_ids])
#     121 )  # identifiers of cross-validation splits
#     122 run_ids = np.sort(
#     123     np.unique(
#     124         ["_".join(x.split("_")[:-1]) for x in run_ids]
#     125     )  # identifiers of hyper-parameters settings
#     126 )
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/abdul-muqeeth/Desktop/ncem/ncem_tutorials/tutorials/grid_searches_gen/210419_INTERACTIONS_BASELINE_NONE_NODES_IMAGE_1_HARTMANN/results/'

# %% [markdown]
# ## Length scales of dependencies for different target cell-types.

# %%
gs.load_target_cell_evaluation()
gs.plot_target_cell_evaluation(
    metric_show="r_squared_linreg",
    metric_select="r_squared_linreg",
    param_x="um_radius",
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 gs.load_target_cell_evaluation()
#       2 gs.plot_target_cell_evaluation(
#       3     metric_show="r_squared_linreg",
#       4     metric_select="r_squared_linreg",
#       5     param_x="um_radius",
#       6 )
#
# File ~/miniconda3/envs/ncem_38/lib/python3.8/site-packages/ncem/train/summaries.py:507, in GridSearchContainer.load_target_cell_evaluation(self, report_unsuccessful_runs)
#     499 indir = self.source_path + gs_id + "/results/"
#     500 # runs_ids are the unique hyper-parameter settings, which are again subsetted by cross-validation.
#     501 # These ids are present in all files names but are only collected from the *model.tf file names here.
#     503 run_ids = np.sort(
#     504     np.unique(
#     505         [
#     506             "_".join(".".join(x.split(".")[:-1]).split("_")[:-1])
# --> 507             for x in os.listdir(indir)
#     508             if x.split("_")[-1].split(".")[0] == "time"
#     509         ]
#     510     )
#     511 )
#     512 cv_ids = np.sort(np.unique([x.split("_")[-1] for x in run_ids]))  # identifiers of cross-validation splits
#     513 run_ids = np.sort(
#     514     np.unique(["_".join(x.split("_")[:-1]) for x in run_ids])  # identifiers of hyper-parameters settings
#     515 )
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/abdul-muqeeth/Desktop/ncem/ncem_tutorials/tutorials/grid_searches_gen/210419_INTERACTIONS_BASELINE_NONE_NODES_IMAGE_1_HARTMANN/results/'

# %% [markdown]
# # 2. Extracting sender-receiver effects with NCEM

# %%
# splitting data into test and validation sets, can be ignored for non sender-receiver focused analysis
interpreter.split_data_node(0.1, 0.1)
interpreter.n_eval_nodes_per_graph = 10
interpreter.cell_names = list(interpreter.data.celldata.uns['node_type_names'].values())
# Out:
# Using split method: node.
#  Train-test-validation split is based on total number of nodes per patients over all images.
#
# Excluded 0 cells with the following unannotated cell type: [None]
#
# Whole dataset: 63747 cells out of 58 images from 4 patients.
# Test dataset: 6376 cells out of 58 images from 4 patients.
# Training dataset: 51914 cells out of 58 images from 4 patients.
# Validation dataset: 5738 cells out of 58 images from 4 patients.

# %%
interpreter.get_sender_receiver_effects()
# Out:
# 100%|████████████████████████████████████████████████████▊| 6351/6374 [02:45<00:00, 38.37it/s]
# using ols parameters.
# (63510, 8)
# (63510, 64)
# X shape: (72, 63510)
# y_ shape: (63510, 36)
# calculating inv fim.

# %% [markdown]
# # Type coupling analysis
#
# Heatmap color is proportional to the number of differentially expressed genes at a FDR-corrected p-value threshold of 0.05 for each pair of sender and receiver cell types.

# %%
interpreter.type_coupling_analysis(figsize=(6.5, 5.5))

# %% [markdown]
# Edge width proportional to the number of differentially expressed genes at a FDR-corrected p-value threshold of 0.05 for each pair of sender and receiver cell types. Only edges with eat least 24 differentially expressed genes are shown.
#
#
# **Arrow thickness:** strength of directional dependencies between cell types as the magnitude of the corresponding coefficient vector

# %%
interpreter.type_coupling_analysis_circular(
    edge_attr='magnitude', 
    edge_width_scale=3.5,
    de_genes_threshold=24,
    figsize=(9,9),
    text_space=1.35
)
# Out:
#                 sender            receiver   0  magnitude  de_genes  \
# 1        CD11c Myeloid         CD4 T cells  20   0.184583  0.551724
# 2        CD11c Myeloid        CD68 Myeloid  19   0.180837  0.517241
# 3        CD11c Myeloid         CD8 T cells   4   0.059416  0.000000
# 4        CD11c Myeloid         Endothelial  17   0.201234  0.448276
# 5        CD11c Myeloid          Epithelial   7   0.183564  0.103448
# 6        CD11c Myeloid          Fibroblast  11   0.187391  0.241379
# 7        CD11c Myeloid  Other immune cells   7   0.201477  0.103448
# 8          CD4 T cells       CD11c Myeloid  29   0.258742  0.862069
# 10         CD4 T cells        CD68 Myeloid  30   0.241639  0.896552
# 11         CD4 T cells         CD8 T cells  14   0.066372  0.344828
# 12         CD4 T cells         Endothelial  28   0.194439  0.827586
# 13         CD4 T cells          Epithelial  30   0.260939  0.896552
# 14         CD4 T cells          Fibroblast  28   0.251973  0.827586
# 15         CD4 T cells  Other immune cells  33   0.342391  1.000000
# 16        CD68 Myeloid       CD11c Myeloid  21   0.349795  0.586207
# 17        CD68 Myeloid         CD4 T cells  21   0.201837  0.586207
# 19        CD68 Myeloid         CD8 T cells  18   0.123444  0.482759
# 20        CD68 Myeloid         Endothelial  14   0.173818  0.344828
# 21        CD68 Myeloid          Epithelial  19   0.195660  0.517241
# 22        CD68 Myeloid          Fibroblast  16   0.146837  0.413793
# 23        CD68 Myeloid  Other immune cells  25   0.245066  0.724138
# 24         CD8 T cells       CD11c Myeloid  28   0.265812  0.827586
# 25         CD8 T cells         CD4 T cells  24   0.176759  0.689655
# 26         CD8 T cells        CD68 Myeloid  28   0.191230  0.827586
# 28         CD8 T cells         Endothelial  17   0.115434  0.448276
# 29         CD8 T cells          Epithelial  28   0.281284  0.827586
# 30         CD8 T cells          Fibroblast  11   0.141674  0.241379
# 31         CD8 T cells  Other immune cells  32   0.397582  0.965517
# 32         Endothelial       CD11c Myeloid  27   0.367173  0.793103
# 33         Endothelial         CD4 T cells   9   0.238002  0.172414
# 34         Endothelial        CD68 Myeloid  29   0.317786  0.862069
# 35         Endothelial         CD8 T cells  23   0.221827  0.655172
# 37         Endothelial          Epithelial  28   0.448291  0.827586
# 38         Endothelial          Fibroblast   8   0.120242  0.137931
# 39         Endothelial  Other immune cells  31   0.289699  0.931034
# 40          Epithelial       CD11c Myeloid  25   0.421383  0.724138
# 41          Epithelial         CD4 T cells  29   0.402205  0.862069
# 42          Epithelial        CD68 Myeloid  25   0.306970  0.724138
# 43          Epithelial         CD8 T cells  31   0.332375  0.931034
# 44          Epithelial         Endothelial  23   0.194670  0.655172
# 46          Epithelial          Fibroblast  25   0.249920  0.724138
# 47          Epithelial  Other immune cells  27   0.258075  0.793103
# 48          Fibroblast       CD11c Myeloid  28   0.239382  0.827586
# 49          Fibroblast         CD4 T cells   8   0.198317  0.137931
# 50          Fibroblast        CD68 Myeloid  27   0.289148  0.793103
# 51          Fibroblast         CD8 T cells  14   0.152868  0.344828
# 52          Fibroblast         Endothelial  14   0.122101  0.344828
# 53          Fibroblast          Epithelial  27   0.368884  0.793103
# 55          Fibroblast  Other immune cells  23   0.207375  0.655172
# 56  Other immune cells       CD11c Myeloid  33   0.434611  1.000000
# 57  Other immune cells         CD4 T cells  29   0.339565  0.862069
# 58  Other immune cells        CD68 Myeloid  33   0.310724  1.000000
# 59  Other immune cells         CD8 T cells  26   0.152515  0.758621
# 60  Other immune cells         Endothelial  22   0.122353  0.620690
# 61  Other immune cells          Epithelial  27   0.307189  0.793103
# 62  Other immune cells          Fibroblast  24   0.202894  0.689655
#
#     de_genes_abs
# 1             20
# 2             19
# 3              4
# 4             17
# 5              7
# 6             11
# 7              7
# 8             29
# 10            30
# 11            14
# 12            28
# 13            30
# 14            28
# 15            33
# 16            21
# 17            21
# 19            18
# 20            14
# 21            19
# 22            16
# 23            25
# 24            28
# 25            24
# 26            28
# 28            17
# 29            28
# 30            11
# 31            32
# 32            27
# 33             9
# 34            29
# 35            23
# 37            28
# 38             8
# 39            31
# 40            25
# 41            29
# 42            25
# 43            31
# 44            23
# 46            25
# 47            27
# 48            28
# 49             8
# 50            27
# 51            14
# 52            14
# 53            27
# 55            23
# 56            33
# 57            29
# 58            33
# 59            26
# 60            22
# 61            27
# 62            24

# %% [markdown]
# # 3. Directional sender effects for Epithelial cells and CD8 T cells
#
# We dissected these couplings based on the gene-wise effects of all senders on one receiver type for CD8T cells and Epithelial cells which contextualizes differential expression results of the CD8T cell–Epithelial cell axis.
#
# NCEM correctly identifies genes and proteins that play roles in T-cell activation, regulation of T-cell antigen receptor signalling and immune response.

# %% [markdown]
# ## a) Sender effects on CD8 T cells
#
# “Sender effect” analysis heatmap for CD8 T cells. Shown is the estimated log fold change that the sender cell type on the y-axis induces in the gene on the x axis in receiving CD8 T cells.

# %%
interpreter.sender_effect(
    receiver='CD8 T cells', 
    gene_subset=['CD8A', 'CD4', 'PTPRC', 'ENTPD1', 'PDCD1', 'CD247'], 
    figsize=(4,5)
)

# %% [markdown]
# ## b) Sender effects on Epithelial cells
#
# “Sender effect” analysis heatmap for Epithelial cells. Shown is the estimated log fold change that the sender cell type on the y-axis induces in the gene on the x axis in receiving Epithelial cells.

# %%
interpreter.sender_effect(
    receiver='Epithelial', 
    gene_subset=['CD8A', 'CD4', 'PTPRC', 'ENTPD1', 'PDCD1', 'CD247'], 
    figsize=(4,5)
)

# %% [markdown]
# ## c) Directional effect for sender-receiver axis for CD8 T cells on Epithelial cells
#
# This analysis contextualizes differential expression results of the CD8 Tcell – Epithelial cell axis.

# %% [markdown]
# Volcano plot of differentially expressed genes of Epithelial cells in the neighborhood of CD8 T cells.

# %%
interpreter.sender_receiver_effect_vulcanoplot(
    sender='CD8 T cells', 
    receiver='Epithelial',
    fold_change_threshold=0.04,
    figsize=(3,5)
)

# %%
# low fold change
interpreter.sender_receiver_values(
    sender='CD8 T cells', 
    receiver='Epithelial'
).sort_values(by='fold change').head(5)
# Out:
#         mean expression    pvalue    qvalue  fold change  -log 10 qvalue
# CD247          0.033484  0.000222  0.000502    -0.052485        3.299011
# CD4            0.443923  0.000481  0.001045    -0.033690        2.980705
# PTPRC          0.092476  0.058306  0.090830    -0.028594        1.041769
# PECAM1         0.019289  0.596243  0.670774    -0.004426        0.173424
# LDHA           0.631155  0.640090  0.706134    -0.003231        0.151113

# %%
# high fold change
interpreter.sender_receiver_values(
    sender='CD8 T cells', 
    receiver='Epithelial'
).sort_values(by='fold change', ascending=False).head(5)
# Out:
#         mean expression        pvalue        qvalue  fold change  \
# ATP1A1         0.601787  0.000000e+00  0.000000e+00     0.102429
# SLC1A5         0.617982  0.000000e+00  0.000000e+00     0.098478
# SLC3A2         0.458504  0.000000e+00  0.000000e+00     0.098254
# CKM            0.491796  1.842970e-14  9.034475e-14     0.084243
# CDH1           0.538660  6.661338e-16  3.636901e-15     0.075619
#
#         -log 10 qvalue
# ATP1A1             inf
# SLC1A5             inf
# SLC3A2             inf
# CKM          13.044097
# CDH1         14.439268

# %% [markdown]
# ## d) Squidpy: Ligand-receptor interactions
#
# Again, these core associations are reproduced by CellphoneDB. However only on  receptor signaling genes. The shown result can be extracted with Squidpy.
#
# NCEM is not limited to receptor signaling genes only.

# %%
adata = interpreter.data.ligrec(
    fraction=0.70,
)
# Out:
# 0.00B [00:00, ?B/s]
# 0.00B [00:00, ?B/s]
# 0.00B [00:00, ?B/s]
# n cells: 44622
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 adata = interpreter.data.ligrec(
#       2     fraction=0.70,
#       3 )
#
# File ~/miniconda3/envs/ncem_38/lib/python3.8/site-packages/ncem/data.py:1311, in PlottingTools.ligrec(self, image_key, source_groups, undefined_type, hgnc_names, fraction, pvalue_threshold, width, seed, random_state, fontsize, save, suffix, show, copy)
#    1302     hgcn_x = pd.DataFrame(temp_adata.X, columns=hgnc_names)
#    1303     temp_adata = AnnData(
#    1304         X=hgcn_x,
#    1305         obs=temp_adata.obs.astype("category"),
#    (...)
#    1308         uns=temp_adata.uns,
#    1309     )
# -> 1311 sq.gr.ligrec(temp_adata, interactions=interactions, cluster_key=cluster_id, use_raw=False, seed=seed)
#    1312 if save is not None:
#    1313     save = save + suffix
#
# File ~/miniconda3/envs/ncem_38/lib/python3.8/site-packages/squidpy/gr/_ligrec.py:662, in ligrec(adata, cluster_key, interactions, complex_policy, threshold, corr_method, corr_axis, use_raw, copy, key_added, gene_symbols, **kwargs)
#     645 """
#     646 %(PT_test.full_desc)s
#     647
#    (...)
#     658 %(ligrec_test_returns)s
#     659 """  # noqa: D400
#     660 with _genesymbols(adata, key=gene_symbols, use_raw=use_raw, make_unique=False):
#     661     return (  # type: ignore[no-any-return]
# --> 662         PermutationTest(adata, use_raw=use_raw)
#     663         .prepare(interactions, complex_policy=complex_policy, **kwargs)
#     664         .test(
#     665             cluster_key=cluster_key,
#     666             threshold=threshold,
#     667             corr_method=corr_method,
#     668             corr_axis=corr_axis,
#     669             copy=copy,
#     670             key_added=key_added,
#     671             **kwargs,
#     672         )
#     673     )
#
# File ~/miniconda3/envs/ncem_38/lib/python3.8/site-packages/squidpy/gr/_ligrec.py:366, in PermutationTestABC.test(self, cluster_key, clusters, n_perms, threshold, seed, corr_method, corr_axis, alpha, copy, key_added, numba_parallel, **kwargs)
#     332 """
#     333 Perform the permutation test as described in :cite:`cellphonedb`.
#     334
#    (...)
#     363 %(ligrec_test_returns)s
#     364 """
#     365 _assert_positive(n_perms, name="n_perms")
# --> 366 _assert_categorical_obs(self._adata, key=cluster_key)
#     368 if corr_method is not None:
#     369     corr_axis = CorrAxis(corr_axis)
#
# File ~/miniconda3/envs/ncem_38/lib/python3.8/site-packages/squidpy/gr/_utils.py:134, in _assert_categorical_obs(adata, key)
#     132 def _assert_categorical_obs(adata: AnnData, key: str) -> None:
#     133     if key not in adata.obs:
# --> 134         raise KeyError(f"Cluster key `{key}` not found in `adata.obs`.")
#     136     if not is_categorical_dtype(adata.obs[key]):
#     137         raise TypeError(f"Expected `adata.obs[{key!r}]` to be `categorical`, found `{infer_dtype(adata.obs[key])}`.")
#
# KeyError: 'Cluster key `Cluster_preprocessed` not found in `adata.obs`.'

# %% [markdown]
# # 4. Sender similarity analysis for Epithelial cells
#
# “Sender similarity analysis” of all sender cell types with respect to Epithelial cell receivers. Shown is a clustered heatmap of Pearson correlation coefficients of the coefficient vectors of each sender type that corresponds to Epithelial cell receivers.
#
# T cell clusters and other immune cells had a similar effect on Epithelial cells in a “sender similarity analysis”, in which we correlated the coefficient vectors of sender cell types that correspond to Epithelial cell receivers, which demonstrates conservation of cell type identity in the sender profile.

# %%
interpreter.sender_similarity_analysis(receiver='Epithelial')

# %% [markdown]
# # 5. Outlook & Announcements
#
# * Custom dataloader functions available soon. (beta version)
#
# * SCOG workshop on spatial omics analysis.
